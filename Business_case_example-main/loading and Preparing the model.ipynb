# %% [markdown]
# # Lets import the preprocessed data and deploy a model for predictions

# %% [markdown]
# ### Importing the data and Libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Data

# %%
npz_train = np.load('/content/drive/MyDrive/Udemy Courses/DATA SCIENCE COURSE/Bussiness Case Example/Audiobooks_data_train.npz')
train_inputs = npz_train['inputs'].astype(np.float)
train_targets = npz_train['targets'].astype(np.int)

npz_validation = np.load('/content/drive/MyDrive/Udemy Courses/DATA SCIENCE COURSE/Bussiness Case Example/Audiobooks_data_validation.npz')
validation_inputs = npz_validation['inputs'].astype(np.float)
validation_targets = npz_validation['targets'].astype(np.int)

npz_test = np.load('/content/drive/MyDrive/Udemy Courses/DATA SCIENCE COURSE/Bussiness Case Example/Audiobooks_data_test.npz')
test_inputs = npz_test['inputs'].astype(np.float)
test_targets = npz_test['targets'].astype(np.int)

# %% [markdown]
# ### Model

# %%
# Set the input and output sizes
input_size = 10
output_size = 2
# Use same hidden layer size for both hidden layers. Not a necessity.
hidden_layer_size = 50
    
# define how the model will look like
model = tf.keras.Sequential([
    # tf.keras.layers.Dense is basically implementing: output = activation(dot(input, weight) + bias)
    # it takes several arguments, but the most important ones for us are the hidden_layer_size and the activation function
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    # the final layer is no different, we just make sure to activate it with softmax
    tf.keras.layers.Dense(output_size, activation='softmax') # output layer
])


### Choose the optimizer and the loss function

# we define the optimizer we'd like to use, 
# the loss function, 
# and the metrics we are interested in obtaining at each iteration
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

### Training
# That's where we train the model we have built.

# set the batch size
batch_size = 100

# set a maximum number of training epochs
max_epochs = 100

# set an early stopping mechanism
# let's set patience=2, to be a bit tolerant against random validation loss increases
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

# fit the model
# note that this time the train, validation and test data are not iterable
model.fit(train_inputs, # train inputs
          train_targets, # train targets
          batch_size=batch_size, # batch size
          epochs=max_epochs, # epochs that we will train for (assuming early stopping doesn't kick in)
          # callbacks are functions called by a task when a task is completed
          # task here is to check if val_loss is increasing
          callbacks=[early_stopping], # early stopping
          validation_data=(validation_inputs, validation_targets), # validation data
          verbose = 2 # making sure we get enough information about the training process
          )
# Out:
# Epoch 1/100
# 36/36 - 1s - loss: 0.5905 - accuracy: 0.6966 - val_loss: 0.5290 - val_accuracy: 0.7271
# Epoch 2/100
# 36/36 - 0s - loss: 0.4612 - accuracy: 0.7754 - val_loss: 0.4615 - val_accuracy: 0.7785
# Epoch 3/100
# 36/36 - 0s - loss: 0.4075 - accuracy: 0.7896 - val_loss: 0.4310 - val_accuracy: 0.7562
# Epoch 4/100
# 36/36 - 0s - loss: 0.3822 - accuracy: 0.7980 - val_loss: 0.4157 - val_accuracy: 0.7673
# Epoch 5/100
# 36/36 - 0s - loss: 0.3676 - accuracy: 0.8039 - val_loss: 0.3989 - val_accuracy: 0.8031
# Epoch 6/100
# 36/36 - 0s - loss: 0.3569 - accuracy: 0.8086 - val_loss: 0.4028 - val_accuracy: 0.7808
# Epoch 7/100
# 36/36 - 0s - loss: 0.3493 - accuracy: 0.8139 - val_loss: 0.3949 - val_accuracy: 0.7875
# Epoch 8/100
# 36/36 - 0s - loss: 0.3452 - accuracy: 0.8122 - val_loss: 0.3923 - val_accuracy: 0.7852
# Epoch 9/100
# 36/36 - 0s - loss: 0.3406 - accuracy: 0.8136 - val_loss: 0.3778 - val_accuracy: 0.8031
# Epoch 10/100
# ...

# %% [markdown]
# ### Testing the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.8259

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.33. Test accuracy: 82.59%
